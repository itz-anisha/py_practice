# %% [markdown]
# <a href="https://colab.research.google.com/github/itz-anisha/py_practice/blob/main/Python_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n=int(input())
k=int(input())
j=int(input())
m=int(input())
p=int(input())

if k<=0 or j<=0 or n<=0 or m<0 or p<0:
 print("INVALID")

else:
 n=n-(m//k + p//j)

 if m%k!=0 or p%j!=0:
  n=n-1

print("Monkeyleft:",n)
# Out:
# 20
# 2
# 3
# 13
# 13
# Monkeyleft: 9

# %%
a=int(input("Enter a number:"))
b=int(input("Enter a number:"))
a=a+b
b=a-b
a=a-b
print("Using + and -")
print("a=",a)
print("b=",b)
# Out:
# Enter a number:2
# Enter a number:3
# Using + and -
# a= 3
# b= 2

# %%
a=int(input("Enter a number:"))
b=int(input("Enter a number:"))
a=a^b
b=a^b
a=a^b
print("Using XOR")
print("a=",a)
print("b=",b)
# Out:
# Enter a number:2
# Enter a number:3
# Using XOR
# a= 3
# b= 2

# %%
a=int(input("Enter a number:"))
b=int(input("Enter a number:"))
temp=a
a=b
b=temp
print("Using temp")
print("a=",a)
print("b=",b)
# Out:
# Enter a number:2
# Enter a number:3
# Using temp
# a= 3
# b= 2

# %%
a=int(input("Enter a number:"))
b=int(input("Enter a number:"))
a,b=b,a
print("Using ,")
print("a=",a)
print("b=",b)
# Out:
# Enter a number:2
# Enter a number:3
# Using ,
# a= 3
# b= 2

# %%
N=int(input("Enter max no. of candies:"))
K=int(input("Enter min no. of candies:"))
C=1
R=N
while(C==1):
  M=int(input("Enter amount of candies needed:"))
  if(M>N):
    print("invalid")
  else:
    R=R-M
    if(R<=K):
      R=N
    print("SOLD=",M)
    print("Remaining=",R)
    C=int(input("DO you want to continue(1or0):"))
# Out:
# Enter max no. of candies:10
# Enter min no. of candies:5
# Enter amount of candies needed:3
# SOLD= 3
# Remaining= 7
# DO you want to continue(1or0):0

# %%
l=[]
n=int(input("Enter the number of elements: "))
for i in range(n):
  l.append(int(input("Enter the elemnts ")))
print(l)
# Out:
# Enter the number of elements: 5
# Enter the elemnts 3
# Enter the elemnts 2
# Enter the elemnts 6
# Enter the elemnts 7
# Enter the elemnts 5
# [3, 2, 6, 7, 5]

# %%
l=[]
n=int(input("Enter the limit:"))
for i in range(n):
  l.append(int(input("Enter the elements:")))
print(l)
large=l[0]
for i in range(1,n):
  if l[i]>large:
    large=l[i]
print("The largest number is ",large)
# Out:
# Enter the limit:5
# Enter the elements:2
# Enter the elements:5
# Enter the elements:6
# Enter the elements:8
# Enter the elements:2
# [2, 5, 6, 8, 2]
# The largest number is  8

# %%
l=[]
n=int(input("Enter the limit:"))
for i in range(n):
  l.append(int(input("Enter the elements:")))
print(l)
small=l[0]
for i in range(1,n):
  if l[i]<small:
    small=l[i]
print("The smallest number is ",small)
# Out:
# Enter the limit:5
# Enter the elements:2
# Enter the elements:5
# Enter the elements:6
# Enter the elements:8
# Enter the elements:2
# [2, 5, 6, 8, 2]
# The smallest number is  2

# %%
l=[]
n=int(input("Enter the limit:"))
for i in range(n):
  l.append(int(input("Enter the elements:")))
print(l)
sum=0
for i in range(n):
 sum=sum+l[i]
print("The sum is ",sum)
# Out:
# Enter the limit:3
# Enter the elements:2
# Enter the elements:4
# Enter the elements:1
# [2, 4, 1]
# The sum is  7

# %%
l=[]
n=int(input("Enter the limit:"))
for i in range(n):
  l.append(int(input("Enter the elements:")))
print(l)
print("The reversed list is ",l[::-1])
# Out:
# Enter the limit:4
# Enter the elements:2
# Enter the elements:4
# Enter the elements:3
# Enter the elements:5
# [2, 4, 3, 5]
# The reversed list is  [5, 3, 4, 2]

# %%
l=[]
n=int(input("Enter the limit: "))
for i in range(n):
 l.append(int(input("Enter the elements: ")))
print(l)
y=int(input("Enter the element that you need to check: "))
j=0
for i in range(n):
  if l[i]==y:
      j=j+1
if j==1:
  print("Element exists")
else:
  print("Element does not exists")
# Out:
# Enter the limit: 4
# Enter the elements: 1
# Enter the elements: 2
# Enter the elements: 3
# Enter the elements: 4
# [1, 2, 3, 4]
# Enter the element that you need to check: 3
# Element exists

# %%
l=[]
n=int(input("Enter the limit: "))
for i in range(n):
 l.append(int(input("Enter the elements: ")))
print(l)
y=int(input("Enter the element that you need to find the number of occurance: "))
count=0
for i in range(n):
  if l[i]==y:
      count=count+1
print("The number of occurance is ",count)
# Out:
# Enter the limit: 5
# Enter the elements: 1
# Enter the elements: 3
# Enter the elements: 2
# Enter the elements: 4
# Enter the elements: 1
# [1, 3, 2, 4, 1]
# Enter the element that you need to find the number of occurance: 1
# The number of occurance is  2

# %%
l=[]
n=int(input("Enter the limit:"))
for i in range(n):
  l.append(int(input("Enter the elements:")))
print("The list is ", l)
l.sort()
print("The sorted list is ", l)
print("The second largest element is ",l[-2])
# Out:
# Enter the limit:3
# Enter the elements:2
# Enter the elements:1
# Enter the elements:3
# The list is  [2, 1, 3]
# The sorted list is  [1, 2, 3]
# The second largest element is  2

# %%
l=[]
n=int(input("Enter the limit: "))
for i in range(n):
  l.append(int(input("Enter the elements: ")))
print(l)
print(list(set(l)))
# Out:
# Enter the limit: 4
# Enter the elements: 2
# Enter the elements: 3
# Enter the elements: 2
# Enter the elements: 3
# [2, 3, 2, 3]
# [2, 3]
