# %% [markdown]
# <a href="https://colab.research.google.com/github/itz-anisha/py_practice/blob/main/Python_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n=int(input())
k=int(input())
j=int(input())
m=int(input())
p=int(input())

if k<=0 or j<=0 or n<=0 or m<0 or p<0:
 print("INVALID")

else:
 n=n-(m//k + p//j)

 if m%k!=0 or p%j!=0:
  n=n-1

print("Monkeyleft:",n)
# Out:
# 20
# 2
# 3
# 13
# 13
# Monkeyleft: 9

# %%
a=int(input("Enter a number:"))
b=int(input("Enter a number:"))
a=a+b
b=a-b
a=a-b
print("Using + and -")
print("a=",a)
print("b=",b)
# Out:
# Enter a number:2
# Enter a number:3
# Using + and -
# a= 3
# b= 2

# %%
a=int(input("Enter a number:"))
b=int(input("Enter a number:"))
a=a^b
b=a^b
a=a^b
print("Using XOR")
print("a=",a)
print("b=",b)
# Out:
# Enter a number:2
# Enter a number:3
# Using XOR
# a= 3
# b= 2

# %%
a=int(input("Enter a number:"))
b=int(input("Enter a number:"))
temp=a
a=b
b=temp
print("Using temp")
print("a=",a)
print("b=",b)
# Out:
# Enter a number:2
# Enter a number:3
# Using temp
# a= 3
# b= 2

# %%
a=int(input("Enter a number:"))
b=int(input("Enter a number:"))
a,b=b,a
print("Using ,")
print("a=",a)
print("b=",b)
# Out:
# Enter a number:2
# Enter a number:3
# Using ,
# a= 3
# b= 2

# %%
N=int(input("Enter max no. of candies:"))
K=int(input("Enter min no. of candies:"))
C=1
R=N
while(C==1):
  M=int(input("Enter amount of candies needed:"))
  if(M>N):
    print("invalid")
  else:
    R=R-M
    if(R<=K):
      R=N
    print("SOLD=",M)
    print("Remaining=",R)
    C=int(input("DO you want to continue(1or0):"))
# Out:
# Enter max no. of candies:10
# Enter min no. of candies:5
# Enter amount of candies needed:3
# SOLD= 3
# Remaining= 7
# DO you want to continue(1or0):0

# %%
l=[]
n=int(input("Enter the number of elements: "))
for i in range(n):
  l.append(int(input("Enter the elemnts ")))
print(l)
# Out:
# Enter the number of elements: 5
# Enter the elemnts 3
# Enter the elemnts 2
# Enter the elemnts 6
# Enter the elemnts 7
# Enter the elemnts 5
# [3, 2, 6, 7, 5]

# %%
l=[]
n=int(input("Enter the limit:"))
for i in range(n):
  l.append(int(input("Enter the elements:")))
print(l)
large=l[0]
for i in range(1,n):
  if l[i]>large:
    large=l[i]
print("The largest number is ",large)
# Out:
# Enter the limit:5
# Enter the elements:2
# Enter the elements:5
# Enter the elements:6
# Enter the elements:8
# Enter the elements:2
# [2, 5, 6, 8, 2]
# The largest number is  8

# %%
l=[]
n=int(input("Enter the limit:"))
for i in range(n):
  l.append(int(input("Enter the elements:")))
print(l)
small=l[0]
for i in range(1,n):
  if l[i]<small:
    small=l[i]
print("The smallest number is ",small)
# Out:
# Enter the limit:5
# Enter the elements:2
# Enter the elements:5
# Enter the elements:6
# Enter the elements:8
# Enter the elements:2
# [2, 5, 6, 8, 2]
# The smallest number is  2

# %%
l=[]
n=int(input("Enter the limit:"))
for i in range(n):
  l.append(int(input("Enter the elements:")))
print(l)
sum=0
for i in range(n):
 sum=sum+l[i]
print("The sum is ",sum)
# Out:
# Enter the limit:3
# Enter the elements:2
# Enter the elements:4
# Enter the elements:1
# [2, 4, 1]
# The sum is  7

# %%
l=[]
n=int(input("Enter the limit:"))
for i in range(n):
  l.append(int(input("Enter the elements:")))
print(l)
print("The reversed list is ",l[::-1])
# Out:
# Enter the limit:4
# Enter the elements:2
# Enter the elements:4
# Enter the elements:3
# Enter the elements:5
# [2, 4, 3, 5]
# The reversed list is  [5, 3, 4, 2]

# %%
l=[]
n=int(input("Enter the limit: "))
for i in range(n):
 l.append(int(input("Enter the elements: ")))
print(l)
y=int(input("Enter the element that you need to check: "))
j=0
for i in range(n):
  if l[i]==y:
      j=j+1
if j==1:
  print("Element exists")
else:
  print("Element does not exists")
# Out:
# Enter the limit: 4
# Enter the elements: 1
# Enter the elements: 2
# Enter the elements: 3
# Enter the elements: 4
# [1, 2, 3, 4]
# Enter the element that you need to check: 3
# Element exists

# %%
l=[]
n=int(input("Enter the limit: "))
for i in range(n):
 l.append(int(input("Enter the elements: ")))
print(l)
y=int(input("Enter the element that you need to find the number of occurance: "))
count=0
for i in range(n):
  if l[i]==y:
      count=count+1
print("The number of occurance is ",count)
# Out:
# Enter the limit: 5
# Enter the elements: 1
# Enter the elements: 3
# Enter the elements: 2
# Enter the elements: 4
# Enter the elements: 1
# [1, 3, 2, 4, 1]
# Enter the element that you need to find the number of occurance: 1
# The number of occurance is  2

# %%
l=[]
n=int(input("Enter the limit:"))
for i in range(n):
  l.append(int(input("Enter the elements:")))
print("The list is ", l)
l.sort()
print("The sort list is ", l)
sorted(l)
print("The sorted list ",l)
print("The second largest element is ",l[-2])
# Out:
# Enter the limit:4
# Enter the elements:3
# Enter the elements:2
# Enter the elements:5
# Enter the elements:7
# The list is  [3, 2, 5, 7]
# The sort list is  [2, 3, 5, 7]
# The sorted list  [2, 3, 5, 7]
# The second largest element is  5

# %%
l=[]
n=int(input("Enter the limit: "))
for i in range(n):
  l.append(int(input("Enter the elements: ")))
print(l)
print(list(set(l)))
# Out:
# Enter the limit: 4
# Enter the elements: 2
# Enter the elements: 3
# Enter the elements: 2
# Enter the elements: 3
# [2, 3, 2, 3]
# [2, 3]

# %%
i=map(int,(input("Enter the elements: ").split()))
print(list(i))
# Out:
# Enter the elements: 23451
# [23451]

# %%
arr =[12,24,30,45,55,60,72]
print(arr[1:3])
print(arr[:4])
print(arr[1:])
print(arr[::-1])
# Out:
# [24, 30]
# [12, 24, 30, 45]
# [24, 30, 45, 55, 60, 72]
# [72, 60, 55, 45, 30, 24, 12]

# %%
n=int(input("Number of students: "))
r=list(map(int, input("Enter the ranks: ").split()))
min=r[0]
c=0
for i in range(1,n):
    if r[i] < min:
        min=r[i]
        c+= 1
print("no.of cuts:",c)
# Out:
# no of students: 6
# Enter the ranks: 2 3 4 1 5 6
# no.of cuts: 1

# %%
r=int(input("Enter the no of rats:"))
u=int(input("Enter the no of units:"))
arr=[]
n=int(input("Enter the no of elements:"))
arr=list(map(int, input("Enter the elements: ").split()))
sum=0
h=0
for i in range(0,n):
  sum = sum + arr[i]
  h+=1
  if(sum >= r*u):
    break;
print("output=",h)
# Out:
# Enter the no of rats:7
# Enter the no of units:2
# Enter the no of elements:8
# Enter the elements: 2 8 3 5 7 4 1 2
# output= 4

# %%
str=input("Enter the string:")
r_str=str[::-1]
print(r_str)
# Out:
# Enter the string:amra
# arma

# %%
n=int(input("enter the number:"))
o=0
while n>0:
  r=n%10
  o=o*10+r
  n=n//10
print("reversed:",o)
# Out:
# enter the number:123
# reversed: 321

# %%
n=int(input("enter the number:"))
s=0
while n>0:
  r=n%10
  s=s+r
  n=n//10
print("sum:",s)
# Out:
# enter the number:231
# sum: 6

# %%
n=int(input("Enter a number: "))
s=0
while n>0:
  a=n%10
  if a>s:
    s=a
  n=n//10
print("Largest digit: ",s)
# Out:
# Enter a number: 234
# Largest:  4

# %%
n=int(input("Enter a number: "))
n1=n
r=0
while n>0:
  a=n%10
  r=r*10+a
  n=n//10
if r==n1:
    print("Palindrome")
else:
    print("Not Palindrome")
# Out:
# Enter a number: 121
# Palindrome

# %%
a=input("Enter your string:")
if a==a[::-1]:
  print("string is palindrom")
else:
  print("String is not palindrom")
# Out:
# Enter your string:121
# string is palindrom

# %%
a=input("Enter the string 1 : ")
b=input("Enter the string 2 : ")
if(sorted(a)==sorted(b)):
  print("anagram")
else:
  print("not anagram")
# Out:
# Enter the string 1 : araa
# Enter the string 2 : raaa
# anagram

# %%
n=input("Enter a string:")
ch=input("Enter character to count:")
count=0
for i in n:
  if i==ch:
    count=count+1
print("count:",count)
# Out:
# enter a string:araa
# enter character to count:a
# count: 3

# %%
str= input("Enter a string: ")
s = ""
for char in str:
    if char not in s:
       s = s + char
print("Without duplicates:",s)
# Out:
# Enter a string: anisha
# Without duplicates: anish

# %%
s=input("Enter the string :")
v=0
c=0
for i in s:
 if(i in "aeiouAEIOU"):
   v+=1
 else:
   c+=1
print("Number of vowels =",v)
print("NUmber of consnant =",c)
# Out:
# Enter the string :anisha
# Number of vowels = 3
# NUmber of consnant = 3

# %%
a=input("Enter your string:")
space=""
for ch in a:
  if ch!=" ":
    space+=ch
print("The string without space:",space)
# Out:
# Enter your string:hello world
# The string without space: helloworld

# %%
a=[]
b=[]
N1=int(input("enter the value of N1:"))
N2=int(input("enter the value of N2:"))
a=list(map(int, input("Enter the elements: ").split()))
b=list(map(int, input("Enter the elements: ").split()))
x=sorted(set(a + b))
l=len(x)
if l%2 != 0:
  print("op=",x[l//2])
else:
  print("op=",(x[l//2-1]+x[l//2])/2)
# Out:
# enter the value of N1:2
# enter the value of N2:3
# Enter the elements: 2 3
# Enter the elements: 4 5 6
# op= 4

# %%
n=int(input("Enter the number"))
a=bin(n)
s=a[2:]
s=s.replace('0','y').replace('1','0').replace('y','1')
print(int(s,2))
# Out:
# Enter the number10
# 5

# %%
a=[]
N=int(input("enter the value of N:"))
a=list(map(int, input("Enter the elements: ").split()))
s=int(input("enter the value of spike:"))
for i in a:
  b=bin(i)
  x=b[2: ]
  x1=x[ :-2]
  if not x1:
      print(0)
  else:
      print(int(x1,2))
# Out:
# enter the value of N:5
# Enter the elements: 1 2 3  4 5
# enter the value of spike:2
# 0
# 0
# 0
# 1
# 1
